# %%
from pyspark import SparkConf, SparkContext
import collections

# %%
conf = SparkConf().setMaster("local").setAppName("WordCount")
sc = SparkContext(conf = conf)

# %%
input = sc.textFile("file:///sparkcourse/Book")
words = input.flatMap(lambda x: x.split())
wordCounts = words.countByValue()
wc=collections.OrderedDict(sorted(wordCounts.items()))
wc
# Out:
# OrderedDict([('"CRM"', 1),
#              ('"Display', 1),
#              ('"Flexibility', 1),
#              ('"Good', 1),
#              ('"How', 1),
#              ('"I', 1),
#              ('"Lean', 1),
#              ('"Measure', 1),
#              ('"Office', 1),
#              ('"Oh,', 1),
#              ('"Only', 1),
#              ('"Plan', 1),
#              ('"Shark', 2),
#              ('"Silver', 1),
#              ('"SilverLining".', 1),
#              ('"The', 4),
#              ('"URL', 1),
#              ('"Why', 1),
#              ('"WordPress', 1),
#              ('"Y', 1),
#              ('"account', 1),
#              ('"acqui-hires."', 1),
#              ('"action"', 2),
#              ('"ad', 1),
#              ('"adaptive"', 1),
#              ('"advertorial"', 1),
#              ('"ageism', 1),
#              ('"audience"', 1),
#              ('"brand', 1),
#              ('"broad', 2),
#              ('"call', 1),
#              ('"call-outs"', 1),
#              ('"campaign', 1),
#              ('"click', 1),
#              ('"come', 1),
#              ('"cost', 1),
#              ('"designed"', 1),
#              ('"dimensions"', 1),
#              ('"goals".', 1),
#              ('"growth', 3),
#              ('"hobby"', 1),
#              ('"how', 3),
#              ('"landing', 1),
#              ('"like"', 2),
#              ('"liking"', 1),
#              ('"link', 2),
#              ('"market', 1),
#              ('"moderately', 1),
#              ('"modern"', 1),
#              ('"moonlighting"', 2),
#              ('"negative', 1),
#              ('"organic', 1),
#              ('"remarketing', 1),
#              ('"remnant', 1),
#              ('"responsive"?', 1),
#              ('"retirement."', 1),
#              ('"search', 2),
#              ('"second', 1),
#              ('"similar', 1),
#              ('"site', 1),
#              ('"skyscraper', 1),
#              ('"soft', 1),
#              ('"spammy"', 1),
#              ('"strongly', 1),
#              ('"their', 1),
#              ('"unlimited', 1),
#              ('"what', 1),
#              ('#1', 1),
#              ('$1,000', 2),
#              ('$1,800', 1),
#              ('$10', 1),
#              ('$10,000', 8),
#              ('$100', 1),
#              ('$100,', 1),
#              ('$100,000', 3),
#              ('$1000', 1),
#              ('$104', 1),
#              ('$11,000', 1),
#              ('$125', 1),
#              ('$150', 1),
#              ('$300', 1),
#              ('$300,000', 2),
#              ('$312', 1),
#              ('$40,000', 2),
#              ('$5', 1),
#              ('$50,000', 2),
#              ('$500', 1),
#              ('$75,000', 2),
#              ('$82.50', 1),
#              ('&', 2),
#              ('("impressions")', 1),
#              ('(A', 1),
#              ('(AWS)', 1),
#              ('(BLS)', 1),
#              ('(CPA)', 1),
#              ('(CPA).', 1),
#              ('(Census', 1),
#              ('(December', 1),
#              ('(FEIN)', 1),
#              ('(I', 1),
#              ("(I've", 1),
#              ('(LPO)', 2),
#              ('(LPO),', 1),
#              ('(LPO?)', 1),
#              ('(MVP),', 1),
#              ('(Month,', 1),
#              ('(NIOSH)', 1),
#              ('(SBA),', 1),
#              ('(SEO)', 1),
#              ('(SEO).', 1),
#              ('(SEO,)', 1),
#              ('(See', 1),
#              ('(W3TC)', 1),
#              ("(You'll", 1),
#              ('(Your', 2),
#              ('(and', 2),
#              ('(arcade', 1),
#              ('(at', 1),
#              ('(be', 1),
#              ('(by', 1),
#              ('(click', 1),
#              ('(dots', 1),
#              ('(free)', 1),
#              ('(go', 1),
#              ('(health', 1),
#              ('(hosted', 1),
#              ('(http://moz.com/learn/seo)', 1),
#              ('(in', 1),
#              ('(including', 1),
#              ('(it�s', 1),
#              ('(like', 1),
#              ('(ones', 1),
#              ('(or', 3),
#              ('(other', 1),
#              ('(pre-tax)', 1),
#              ('(someone', 1),
#              ('(such', 2),
#              ('(that', 1),
#              ('(that�s', 1),
#              ('(the', 1),
#              ('(unless', 2),
#              ('(�Obamacare�,)', 1),
#              ('*', 22),
#              ('***', 1),
#              ('--', 2),
#              ('---------------', 2),
#              ('------------------------------------------------------------',
#               2),
#              ('.com', 1),
#              ('0-5:', 1),
#              ('1', 2),
#              ('1%', 4),
#              ('10', 6),
#              ('10%', 6),
#              ('10%?', 1),
#              ('100', 1),
#              ('100%', 4),
#              ('1099', 1),
#              ('11', 2),
#              ('12', 1),
#              ('13', 1),
#              ('14%', 1),
#              ('15%', 1),
#              ('17.9', 1),
#              ('18%', 1),
#              ('19,', 1),
#              ('1:1', 1),
#              ('1:1124.', 1),
#              ('2', 4),
#              ('2,', 1),
#              ('20%', 3),
#              ('20-mile', 1),
#              ('20-something', 1),
#              ('2006,', 1),
#              ('20081,', 1),
#              ('2009.', 1),
#              ('2010', 1),
#              ('2010,', 1),
#              ('2010.', 1),
#              ('2011', 1),
#              ('2011.', 2),
#              ('2012', 7),
#              ('2012,', 1),
#              ('2013', 1),
#              ('2014', 2),
#              ('2014)', 1),
#              ('2014.', 4),
#              ('2015', 3),
#              ('2015,', 1),
#              ('212,000', 1),
#              ('22', 1),
#              ('22%', 1),
#              ('27,', 1),
#              ('28%', 1),
#              ('29%', 2),
#              ('3', 6),
#              ('3%?', 1),
#              ('3,000', 1),
#              ('3-D', 2),
#              ('3-hour', 1),
#              ('300', 2),
#              ('360', 1),
#              ('3?', 1),
#              ('3D', 2),
#              ('4', 6),
#              ('4,', 1),
#              ('4-Hour', 1),
#              ('4.6', 1),
#              ('40', 1),
#              ('40%', 1),
#              ('401(K)', 1),
#              ('41%', 1),
#              ('41,', 1),
#              ('43', 1),
#              ('46%', 2),
#              ('46.7', 1),
#              ('47', 1),
#              ('49.3%', 1),
#              ('5', 6),
#              ('50', 4),
#              ('50%', 5),
#              ('50/50', 2),
#              ('55', 1),
#              ('55%', 1),
#              ('6', 2),
#              ('6%', 1),
#              ('6-8:', 1),
#              ('60', 1),
#              ('62', 3),
#              ('65', 1),
#              ('68%', 1),
#              ('7', 3),
#              ('70%', 1),
#              ('7?', 1),
#              ('8', 4),
#              ('8-10:', 1),
#              ('8-plus-hour-day', 1),
#              ('85%', 1),
#              ('9', 5),
#              ('9-5', 1),
#              ('9-5,', 1),
#              ('9-5.', 2),
#              ('90%', 2),
#              ('90%.', 1),
#              ('93%', 1),
#              ('99-101.', 1),
#              ('<alt>', 1),
#              ('<h1>,', 1),
#              ('<h2>,', 1),
#              ('<title>,', 1),
#              ('A', 39),
#              ('ABOUT', 1),
#              ('ACKNOWLEDGMENTS', 1),
#              ('ACT', 1),
#              ('ADAPTING', 1),
#              ('ADVERTISING', 1),
#              ('ADVICE', 1),
#              ('AGREEMENT', 1),
#              ('ALONE', 1),
#              ('AM', 4),
#              ('AM,', 1),
#              ('AM.', 1),
#              ('AND', 8),
#              ('AS', 1),
#              ('AUTHOR', 1),
#              ('AVOIDING', 1),
#              ('Aaron', 2),
#              ('Aaron�s', 1),
#              ('About', 4),
#              ('Accept', 2),
#              ('According', 5),
#              ('Achieving', 1),
#              ('Acknowledgments', 1),
#              ('Act', 2),
#              ('Act,"', 1),
#              ('Ad', 2),
#              ('AdSense', 1),
#              ('AdSense,', 1),
#              ('AdWords', 23),
#              ("AdWords'", 1),
#              ('AdWords,', 6),
#              ('Adapting', 1),
#              ('Adding', 1),
#              ('Additional', 1),
#              ('Administration', 2),
#              ('Administration,', 1),
#              ('Ads', 3),
#              ('Advertising', 3),
#              ('Advice', 1),
#              ('Affordable', 1),
#              ('After', 3),
#              ('Again,', 2),
#              ('Ageism', 1),
#              ('Ageist,', 1),
#              ('AgileSrc', 1),
#              ('AgileSrc,', 2),
#              ('Agreement', 1),
#              ('Alerts', 1),
#              ('Alexa,', 1),
#              ('All', 13),
#              ('Alone', 1),
#              ('Also', 3),
#              ('Also,', 4),
#              ('Although', 5),
#              ('Always', 3),
#              ('Am', 1),
#              ('Amazon', 2),
#              ("Amazon's", 2),
#              ('Amazon,', 3),
#              ('Amazon.', 1),
#              ('Amazon.com', 1),
#              ('American', 4),
#              ('Americans', 1),
#              ('An', 6),
#              ('Analytics', 10),
#              ('Analytics,', 5),
#              ('Analytics.', 1),
#              ('And', 14),
#              ('And,', 2),
#              ("Angie's", 1),
#              ('Another', 2),
#              ('Answer', 1),
#              ('Anywhere,', 1),
#              ('Apart', 1),
#              ('App', 1),
#              ('Apple,', 1),
#              ('Are', 23),
#              ('Arm', 1),
#              ('Armed', 2),
#              ('As', 45),
#              ('Asia', 1),
#              ('Ask', 4),
#              ('Assembly.', 1),
#              ('Association,', 1),
#              ('Assume', 1),
#              ('Assuming', 1),
#              ('At', 24),
#              ('Attention-Grabbing', 1),
#              ('Austin,', 1),
#              ('Author', 1),
#              ('Automated', 1),
#              ('Automation', 1),
#              ('Average', 1),
#              ('Avoid', 2),
#              ('Avoiding', 2),
#              ('B"', 1),
#              ('B2B', 1),
#              ('BASICS', 5),
#              ('BEWARE', 5),
#              ('BIG', 1),
#              ('BLANKET', 1),
#              ('BLS', 1),
#              ('BOSS', 1),
#              ('BUILDING', 2),
#              ('BUSINESS', 10),
#              ('Bank', 1),
#              ('Banner', 2),
#              ('Based', 1),
#              ('Basics', 5),
#              ('Be', 11),
#              ('Bear', 1),
#              ('Because', 1),
#              ('Become', 1),
#              ('Before', 3),
#              ('Being', 2),
#              ('Beware', 5),
#              ('Beyond', 1),
#              ('Big', 1),
#              ('Bing,', 1),
#              ('Binging', 1),
#              ('Blanket', 1),
#              ('Bob', 1),
#              ('Bob,', 1),
#              ('Books.', 1),
#              ('Boss', 1),
#              ('Boston.', 1),
#              ('Both', 2),
#              ('Brainstorm', 1),
#              ('Brookings', 1),
#              ('Brutal', 1),
#              ('Bryc', 1),
#              ('Build', 2),
#              ('Builder"', 1),
#              ('Building', 5),
#              ('Bureau', 2),
#              ('Bureau,', 1),
#              ('Bus', 1),
#              ('Business', 19),
#              ('Business,', 2),
#              ('Business-to-business?', 1),
#              ('Businesses.', 1),
#              ('But', 38),
#              ('But,', 12),
#              ('Buying', 1),
#              ('By', 9),
#              ('C#', 1),
#              ('C++', 1),
#              ('C-suite.', 1),
#              ('CAMPAIGNS', 1),
#              ('CARE', 1),
#              ('CAREER', 1),
#              ('CARROT', 1),
#              ('CASE', 1),
#              ('CEO', 2),
#              ('CEO!', 1),
#              ("CEO's", 3),
#              ('CEO,', 2),
#              ('CEO.', 1),
#              ('CHECK', 1),
#              ('CHECKLIST', 1),
#              ('CITY,', 1),
#              ('CLOSING', 1),
#              ('COBRA', 2),
#              ('COMMUTE', 1),
#              ('COMPOUNDING', 1),
#              ('CONSIDER', 1),
#              ('CONTENTS', 1),
#              ('CPA', 4),
#              ("CPA's", 2),
#              ('CPA,', 2),
#              ('CPA�s', 1),
#              ('CRM', 2),
#              ('CSS', 1),
#              ('CTR', 1),
#              ('Cache', 1),
#              ('California', 1),
#              ('California,', 1),
#              ('Campaigns', 1),
#              ('Can', 21),
#              ('Canada,', 1),
#              ('Car?�,', 1),
#              ('Care', 2),
#              ('Career', 1),
#              ('Carrot', 1),
#              ('Case', 1),
#              ('Catch-22', 1),
#              ('Census', 1),
#              ('Centers', 1),
#              ('Central', 3),
#              ('Certain', 1),
#              ('Chances', 1),
#              ('Channels', 1),
#              ('Channels:', 1),
#              ('Check', 4),
#              ('Checking', 1),
#              ('Checklist', 1),
#              ('China"', 1),
#              ('China,', 2),
#              ('China.', 1),
#              ('Choosing', 1),
#              ('Closing', 1),
#              ('Combinator"', 1),
#              ('Come', 1),
#              ('Commercial', 1),
#              ('Community', 1),
#              ('Commute', 1),
#              ('Companies', 1),
#              ('Companies",', 1),
#              ('Company', 2),
#              ('Company)', 1),
#              ('Compare', 1),
#              ('Compounding', 1),
#              ('Congratulations!', 1),
#              ('Congress', 1),
#              ('Conservatively,', 1),
#              ('Consider', 5),
#              ('Constant', 2),
#              ('Consulting.', 1),
#              ('Contact', 2),
#              ('Contact,', 1),
#              ('Continuous', 1),
#              ('Control10,', 1),
#              ('Conventional', 1),
#              ('Conversions:', 1),
#              ('Copyright', 1),
#              ('Costs', 3),
#              ('Could', 2),
#              ('Council', 1),
#              ('Council,', 1),
#              ('Countless', 1),
#              ('Countries', 1),
#              ('County.', 1),
#              ('Coursera,', 2),
#              ('Courses.', 1),
#              ('Cover', 1),
#              ('Crash', 1),
#              ('Create', 1),
#              ('Creating', 1),
#              ('Creating,', 1),
#              ('Crown', 1),
#              ('Customer', 2),
#              ('Customers', 1),
#              ('Customizing', 1),
#              ('DECISION', 1),
#              ('DEFINITION', 1),
#              ('DEPENDENCIES', 1),
#              ('DESCRIPTION', 2),
#              ('DESIGNING', 1),
#              ('DEVELOPING', 1),
#              ('DHHS', 1),
#              ('DISCLAIMER', 1),
#              ("DON'T", 1),
#              ('DPI', 1),
#              ('DPI.', 1),
#              ('Dad.', 1),
#              ('Dada', 1),
#              ('Daniel', 1),
#              ('Dartmouth,', 1),
#              ('Day', 1),
#              ('Deborah', 1),
#              ('Decision', 1),
#              ('Definition', 1),
#              ('Dental', 2),
#              ('Department', 1),
#              ('Dependencies', 1),
#              ('Depending', 3),
#              ('Describe', 3),
#              ('Description', 2),
#              ('Designing', 1),
#              ('Despite', 1),
#              ('Develop', 1),
#              ('Developing', 1),
#              ('Did', 2),
#              ("Didn't", 1),
#              ('Digging', 1),
#              ('DirectX', 1),
#              ('Director', 1),
#              ('Director-level', 1),
#              ('Discarding', 1),
#              ('Disclaimer', 1),
#              ('Disease', 1),
#              ('Do', 19),
#              ('Does', 2),
#              ('Doing', 3),
#              ("Don't", 22),
#              ('Done?', 1),
#              ('Don�t', 1),
#              ('Doubling', 1),
#              ('Dummies,', 1),
#              ('Dummies.', 1),
#              ('Dummies�', 1),
#              ('Dykstra,', 1),
#              ('E-mail', 1),
#              ('EBay,', 2),
#              ('EFFECT', 1),
#              ('EGO', 1),
#              ('ELSE', 1),
#              ('EMAIL', 1),
#              ('EMPLOYER', 1),
#              ('EMPLOYMENT', 1),
#              ('ENGINE', 2),
#              ('EVALUATING', 1),
#              ('EVEN', 1),
#              ('Earning', 1),
#              ('Economic', 1),
#              ('Editors', 1),
#              ('Effect', 1),
#              ('Effective', 1),
#              ('Ego', 1),
#              ('Elance', 1),
#              ('Eliminating', 1),
#              ('Else', 1),
#              ('Email', 5),
#              ('Emails', 1),
#              ('Employer', 2),
#              ('Employment', 1),
#              ('Engine', 2),
#              ('English', 3),
#              ('English,', 1),
#              ('English.', 1),
#              ('Entrepreneurs', 1),
#              ('Eric', 2),
#              ('Eric.', 1),
#              ('Escape', 1),
#              ('Especially', 1),
#              ('Estimating', 1),
#              ('Etsy,', 1),
#              ('Etsy.', 1),
#              ('Europe', 1),
#              ('Evaluate', 1),
#              ('Evaluating', 1),
#              ('Even', 35),
#              ('Every', 4),
#              ('Everyone', 2),
#              ("Everyone's", 1),
#              ('Exactly', 1),
#              ('Expenses', 1),
#              ('Explain', 1),
#              ('Express�s', 1),
#              ('FAA.', 1),
#              ('FAILURE', 1),
#              ('FALLACY', 1),
#              ('FEAR', 1),
#              ('FINAL', 1),
#              ('FINANCIAL', 2),
#              ('FINDING', 3),
#              ('FIRE', 1),
#              ('FIXED', 1),
#              ('FLOWCHART:', 1),
#              ('FOR', 3),
#              ('FREEDOM', 3),
#              ('FUELING', 1),
#              ('Face', 1),
#              ('FaceBook', 1),
#              ('Facebook', 15),
#              ('Facebook,', 3),
#              ('Facebook?', 1),
#              ('Failure', 1),
#              ('Fallacy', 1),
#              ('Far', 1),
#              ('Fear', 1),
#              ('Federal', 1),
#              ('Fees', 1),
#              ("Ferriss's", 1),
#              ('Ferriss,', 1),
#              ('Few', 1),
#              ('Figure', 2),
#              ('Fiji?', 1),
#              ('Final', 1),
#              ('Finally,', 5),
#              ('Finally�', 1),
#              ('Financial', 3),
#              ('Find', 2),
#              ('Finding', 4),
#              ('Fire', 1),
#              ('First', 3),
#              ('First,', 2),
#              ('Fixed', 1),
#              ('Fla.', 1),
#              ('Florida', 4),
#              ('Florida:', 1),
#              ('Flowchart:', 1),
#              ('Focus', 1),
#              ('For', 19),
#              ('Forbes,', 1),
#              ('Founded', 1),
#              ('Founder,', 1),
#              ('Four', 1),
#              ('Frank', 10),
#              ("Frank's", 1),
#              ('Free', 1),
#              ('Freed', 1),
#              ('Freedom', 7),
#              ('Freelance', 4),
#              ('Freelancers', 1),
#              ('From', 1),
#              ('Fueling', 1),
#              ('Furthermore,', 1),
#              ('GO', 2),
#              ('GROWTH', 3),
#              ('GUILT', 1),
#              ('Gallup', 1),
#              ('Gaming', 1),
#              ('Geared', 1),
#              ('General', 1),
#              ('Generally', 2),
#              ('Germany,', 1),
#              ('Get', 6),
#              ('Gets', 1),
#              ('Getting', 3),
#              ('Given', 1),
#              ('Giving', 1),
#              ('Glass', 1),
#              ('Go', 7),
#              ('GoDaddy.com', 1),
#              ("God's", 1),
#              ('Good', 1),
#              ('Google', 53),
#              ("Google's", 3),
#              ('Google,', 4),
#              ('Google.', 2),
#              ('Google."', 1),
#              ('Grow.', 1),
#              ('Growing', 1),
#              ('Growth', 4),
#              ('Guide', 1),
#              ('Guilt', 1),
#              ('H.S.A.', 1),
#              ('HAPPEN', 1),
#              ('HAVE', 1),
#              ('HAVING', 1),
#              ('HEALTH', 1),
#              ('HIRE', 1),
#              ('HIRING', 1),
#              ('HOW', 1),
#              ('HTML', 1),
#              ('Had', 4),
#              ('Hal', 1),
#              ('Hal.', 1),
#              ('Hanging', 1),
#              ('Happen', 1),
#              ('Harmony,', 1),
#              ('Harper', 1),
#              ('Have', 9),
#              ('Having', 2),
#              ('Hawaii', 1),
#              ('Hawaii?', 1),
#              ('He', 3),
#              ('Headline', 1),
#              ('Headset', 1),
#              ('Health', 2),
#              ('Hell', 1),
#              ('Here', 8),
#              ("Here's", 7),
#              ('Hire', 1),
#              ('Hiring', 3),
#              ('Hopefully', 2),
#              ('Hopefully,', 2),
#              ('Hour', 1),
#              ('How', 29),
#              ('However,', 6),
#              ('Human', 1),
#              ('I', 322),
#              ("I'd", 1),
#              ("I'll", 3),
#              ("I'm", 25),
#              ("I've", 23),
#              ('I:', 2),
#              ('IAG', 1),
#              ('IDEA', 1),
#              ('IDEAL', 1),
#              ('IDEAS', 2),
#              ('II:', 2),
#              ('III:', 2),
#              ('IMDb', 1),
#              ('IMDb.com,', 1),
#              ('IMPORTANCE', 1),
#              ('IN', 1),
#              ('INDOCTRINATION', 1),
#              ('INERTIA', 1),
#              ('INTERPRETING', 1),
#              ('INTRODUCING', 1),
#              ('INVESTING', 1),
#              ('IRS', 2),
#              ('IS', 1),
#              ('IT', 4),
#              ('IT�S', 1),
#              ('Idea', 1),
#              ('Ideal', 1),
#              ('Ideally', 1),
#              ('Ideally,', 4),
#              ('Ideas', 2),
#              ('Identification', 1),
#              ('Identifying', 1),
#              ('If', 237),
#              ('Images', 1),
#              ('Impact', 1),
#              ('Importance', 1),
#              ('In', 41),
#              ('Inc.,', 1),
#              ('Increasing', 1),
#              ('Incubation', 1),
#              ('Indoctrination', 2),
#              ('Industry', 4),
#              ('Industry-specific', 1),
#              ('Inertia', 1),
#              ('Innovation', 1),
#              ('Insert', 1),
#              ('Insider11.', 1),
#              ('Instagram,', 1),
#              ('Instagram.', 1),
#              ('Instead', 3),
#              ('Instead,', 4),
#              ('Institution,', 1),
#              ('Internet', 13),
#              ('Internet,', 6),
#              ('Internet-based', 4),
#              ('Internet.', 3),
#              ('Interpreting', 1),
#              ('Introducing', 1),
#              ('Investing', 3),
#              ('Investors', 1),
#              ('Iraq,', 1),
#              ('Iraq.', 1),
#              ('Is', 17),
#              ('It', 42),
#              ("It's", 46),
#              ('It.', 2),
#              ('Its', 3),
#              ('It�s', 6),
#              ('I�d', 1),
#              ('I�ll', 1),
#              ('I�m', 5),
#              ('I�ve', 1),
#              ('J.', 1),
#              ('Join', 1),
#              ('Jose,', 1),
#              ('Just', 11),
#              ('KEY', 1),
#              ('Kahneman', 1),
#              ('Kane', 7),
#              ('Kane,', 2),
#              ('Kane.', 1),
#              ('Keep', 7),
#              ('Keeping', 1),
#              ('Key', 1),
#              ('LANDING', 1),
#              ('LAST', 1),
#              ('LAUNCHING', 1),
#              ('LEECHES', 1),
#              ('LETTING', 1),
#              ('LICENSES', 1),
#              ('LIFE', 1),
#              ('LIFESTYLE', 4),
#              ('LITTLE', 1),
#              ('LIVE', 2),
#              ('LLC', 3),
#              ('LLC,', 3),
#              ('LPO', 2),
#              ('LPO,', 1),
#              ('LPO.', 1),
#              ('Labor', 2),
#              ('Laminar', 1),
#              ('Landing', 4),
#              ('Last', 1),
#              ('Launching', 2),
#              ('Lean', 4),
#              ('Leave', 1),
#              ('Leaving', 2),
#              ('Leeches', 1),
#              ('Let', 1),
#              ("Let's", 8),
#              ('Letting', 1),
#              ('Let�s', 2),
#              ('Liability', 2),
#              ('Licenses', 1),
#              ('Life', 2),
#              ('Lifestyle', 5),
#              ('Like', 2),
#              ('Likes', 1),
#              ('Limited', 2),
#              ('Lining', 1),
#              ('LinkedIn', 9),
#              ('LinkedIn,', 2),
#              ('List', 1),
#              ('Listen', 1),
#              ('Little', 1),
#              ('Live', 3),
#              ('Living', 1),
#              ('Load', 1),
#              ('Local', 1),
#              ('Look', 4),
#              ('Looking', 3),
#              ('MAKING', 4),
#              ('MANAGEMENT', 2),
#              ('MARKET', 1),
#              ('MARKETING', 2),
#              ('MEASURE', 1),
#              ('MEASURING', 1),
#              ('METRICS', 1),
#              ('MISLEADING', 1),
#              ('MITIGATION', 1),
#              ('MVP', 1),
#              ('Mail', 1),
#              ('MailChimp', 4),
#              ('Maintaining', 2),
#              ('Maintenance', 1),
#              ('Major', 1),
#              ('Make', 15),
#              ('Making', 5),
#              ('Management', 2),
#              ('Management,', 1),
#              ('Many', 7),
#              ('Market', 2),
#              ('Marketing', 5),
#              ('Marketplace', 1),
#              ('Massachusetts', 1),
#              ('May', 1),
#              ('Maybe', 13),
#              ('Meanwhile', 1),
#              ('Meanwhile,', 1),
#              ('Measure', 1),
#              ('Measuring', 1),
#              ('Medicare', 2),
#              ('Meetup', 4),
#              ('Metrics', 2),
#              ('Michal', 3),
#              ('Military', 1),
#              ('Minimizing', 1),
#              ('Misleading', 1),
#              ('Mitigation', 1),
#              ('Mohammed', 1),
#              ('Mohammed,', 1),
#              ('Moleskine', 1),
#              ('Mom', 1),
#              ('More', 2),
#              ('Most', 8),
#              ('Moz.com', 1),
#              ('Much', 1),
#              ('Multiply', 1),
#              ('My', 16),
#              ('NAMING', 1),
#              ('NASA', 1),
#              ('NET', 1),
#              ('NETWORKS', 1),
#              ('NEW', 1),
#              ('NO', 2),
#              ('NOT', 2),
#              ('Naming', 1),
#              ('National', 1),
#              ('Need', 1),
#              ('Neomek', 1),
#              ('Net', 2),
#              ('Networks', 1),
#              ('New', 6),
#              ('News', 1),
#              ('Next,', 1),
#              ('No', 14),
#              ('Nobel', 1),
#              ('Nobody', 6),
#              ("Nobody's", 4),
#              ('None', 1),
#              ('Not', 7),
#              ('Note', 2),
#              ('Notice', 1),
#              ('Now', 4),
#              ('Now,', 4),
#              ('Number', 2),
#              ('OBTAINING', 1),
#              ('OF', 16),
#              ('OFFLINE', 1),
#              ('OK', 6),
#              ('OK.', 1),
#              ('ON', 2),
#              ('ONLINE', 1),
#              ('OPEN', 1),
#              ('OPTIMIZATION', 2),
#              ('ORGANIZATION', 1),
#              ('ORLANDO,', 1),
#              ('OTHER', 1),
#              ('OVERCOMING', 1),
#              ('Obtaining', 1),
#              ('Ocean', 7),
#              ('Oceans', 1),
#              ('Oculus', 5),
#              ('Odds', 2),
#              ('Of', 3),
#              ('Office', 2),
#              ('Offline', 1),
#              ('Often', 1),
#              ('Often,', 3),
#              ('Oftentimes,', 1),
#              ('Once', 23),
#              ('One', 12),
#              ('Ongoing', 1),
#              ('Ongoing,', 1),
#              ('Online', 8),
#              ('Only', 1),
#              ('OpenGL', 1),
#              ('Optimization', 3),
#              ('Or', 3),
#              ('Or,', 1),
#              ('Orange', 1),
#              ('Organization', 1),
#              ('Orlando', 4),
#              ('Orlando,', 2),
#              ('Other', 4),
#              ('Otherwise', 1),
#              ('Otherwise,', 2),
#              ('Out', 1),
#              ('Over', 2),
#              ('Overcoming', 1),
#              ('PAGE', 1),
#              ('PART', 5),
#              ("PC's,", 1),
#              ('PC,', 1),
#              ('PEOPLE', 1),
#              ('PERSONAL', 1),
#              ('PITFALLS', 1),
#              ('PLAN', 3),
#              ('PLANNING', 3),
#              ('PM.', 2),
#              ('PNG,', 1),
#              ('POINTS', 1),
#              ('POTENTIAL', 1),
#              ('PR', 6),
#              ('PR,', 3),
#              ('PREFACE', 1),
#              ('PRESSURE', 1),
#              ('PRODUCT', 1),
#              ('PRODUCT,', 1),
#              ('PROTECTION', 1),
#              ('PUBLIC', 1),
#              ('PULLING', 1),
#              ('Page', 2),
#              ('Page:', 1),
#              ('Park', 1),
#              ('Part', 2),
#              ('Participate', 1),
#              ('Patent', 1),
#              ('Pay', 2),
#              ('Paying', 2),
#              ('People', 4),
#              ('Perhaps', 17),
#              ('Personal', 3),
#              ('Personally,', 2),
#              ('Philippines', 1),
#              ('Physical', 1),
#              ('Pinterest', 1),
#              ('Pitfalls', 1),
#              ('Plan', 4),
#              ...])

# %%
for word, count in wordCounts:
    cleanWord = word.encode('ascii', 'ignore')
    if (cleanWord):
        print(cleanWord.decode() + " " + str(count))
